# %%
tarefas = []

def main():
  print('Bem vindo ao Sistema de Gerenciamento de Tarefas.')
  while True:
    print("\nMenu:")
    print("1. Adicionar Tarefa")
    print("2. Visualizar Tarefas")
    print("3. Marcar Tarefa como Concluída")
    print("4. Remover Tarefa")
    print("5. Sair")

    escolha = input('Digite o número que corresponde a opção desejada: ')

    if escolha == '1':
      descricao = input('Digite a descrição da tarefa: ')
      adicionar_tarefa(descricao)
    elif escolha == '2':
      visualizar_tarefas()
    elif escolha == '3':
      visualizar_tarefas()
      try:
        indice = int(input('Digite o número da tarefa que você deseja marcar como concluída: ')) - 1
        marcar_concluida(indice)
      except ValueError:
        print('Entrada inválida! Por favor digite um número!')
    elif escolha == '4':
      visualizar_tarefas()
      try:
        indice = int(input('Digite o número da tarefa que você deseja remover: ')) - 1
        remover_tarefa(indice)
      except ValueError:
        print('Entrada inválida! Por favor digite um número! ')
    elif escolha == '5':
      print('Saindo do Sistema! Até breve!')
      break
    else:
      print('Opção inválida! Por favor, tente novamente')

def adicionar_tarefa(descricao):
  tarefas.append({'descricao': descricao, 'concluida': False})
  print(f'Tarefa "{descricao}" adicionada com sucesso!')

def visualizar_tarefas():
  if not tarefas:
    print('Nenhuma tarefa foi encontrada!')
    return
  print('\nLista de Tarefas: ')
  for i, tarefa in enumerate(tarefas):
    status = '[X]' if tarefa['concluida'] else '[ ]'
    print(f'{i+ 1}. {status} {tarefa['descricao']}')

def marcar_concluida(indice):
  if 0 <= indice <= len(tarefas):
    tarefas[indice]['concluida'] = True
    print(f'Tarefa "{tarefas[indice]["descricao"]}" foi marcada como concluída!')
  else:
    print('Índice de tarefa inválido!')

def remover_tarefa(indice):
  if 0 <= indice <= len(tarefas):
    descricao = tarefas.pop(indice)['descricao']
    print(f'Tarefa "{descricao}" foi removida com sucesso!')
  else:
    print('Índice de Tarefa inválido!')

# %%
main()
# Out:
# Bem vindo ao Sistema de Gerenciamento de Tarefas.
#
# Menu:
# 1. Adicionar Tarefa
# 2. Visualizar Tarefas
# 3. Marcar Tarefa como Concluída
# 4. Remover Tarefa
# 5. Sair
# Digite o número que corresponde a opção desejada: 1
# Digite a descrição da tarefa: arrumar a casa
# Tarefa "arrumar a casa" adicionada com sucesso!
#
# Menu:
# 1. Adicionar Tarefa
# 2. Visualizar Tarefas
# 3. Marcar Tarefa como Concluída
# 4. Remover Tarefa
# 5. Sair
# Digite o número que corresponde a opção desejada: 1
# Digite a descrição da tarefa: limpar tudo
# Tarefa "limpar tudo" adicionada com sucesso!
#
# Menu:
# 1. Adicionar Tarefa
# 2. Visualizar Tarefas
# 3. Marcar Tarefa como Concluída
# 4. Remover Tarefa
# 5. Sair
# Digite o número que corresponde a opção desejada: 1
# Digite a descrição da tarefa: preparar para viajar
# Tarefa "preparar para viajar" adicionada com sucesso!
#
# Menu:
# 1. Adicionar Tarefa
# 2. Visualizar Tarefas
# 3. Marcar Tarefa como Concluída
# 4. Remover Tarefa
# 5. Sair
# Digite o número que corresponde a opção desejada: 2
#
# Lista de Tarefas:
# 1. [ ] arrumar a casa
# 2. [ ] limpar tudo
# 3. [ ] preparar para viajar
#
# Menu:
# 1. Adicionar Tarefa
# 2. Visualizar Tarefas
# 3. Marcar Tarefa como Concluída
# 4. Remover Tarefa
# 5. Sair
# Digite o número que corresponde a opção desejada: 3
#
# Lista de Tarefas:
# 1. [ ] arrumar a casa
# 2. [ ] limpar tudo
# 3. [ ] preparar para viajar
# Digite o número da tarefa que você deseja marcar como concluída: 2
# Tarefa "limpar tudo" foi marcada como concluída!
#
# Menu:
# 1. Adicionar Tarefa
# 2. Visualizar Tarefas
# 3. Marcar Tarefa como Concluída
# 4. Remover Tarefa
# 5. Sair
# Digite o número que corresponde a opção desejada: 3
#
# Lista de Tarefas:
# 1. [ ] arrumar a casa
# 2. [X] limpar tudo
# 3. [ ] preparar para viajar
# Digite o número da tarefa que você deseja marcar como concluída: 1
# Tarefa "arrumar a casa" foi marcada como concluída!
#
# Menu:
# 1. Adicionar Tarefa
# 2. Visualizar Tarefas
# 3. Marcar Tarefa como Concluída
# 4. Remover Tarefa
# 5. Sair
# Digite o número que corresponde a opção desejada: 4
#
# Lista de Tarefas:
# 1. [X] arrumar a casa
# 2. [X] limpar tudo
# 3. [ ] preparar para viajar
# Digite o número da tarefa que você deseja remover: 3
# Tarefa "preparar para viajar" foi removida com sucesso!
#
# Menu:
# 1. Adicionar Tarefa
# 2. Visualizar Tarefas
# 3. Marcar Tarefa como Concluída
# 4. Remover Tarefa
# 5. Sair
# Digite o número que corresponde a opção desejada: 4
#
# Lista de Tarefas:
# 1. [X] arrumar a casa
# 2. [X] limpar tudo
# Digite o número da tarefa que você deseja remover: 2
# Tarefa "limpar tudo" foi removida com sucesso!
#
# Menu:
# 1. Adicionar Tarefa
# 2. Visualizar Tarefas
# 3. Marcar Tarefa como Concluída
# 4. Remover Tarefa
# 5. Sair
# Digite o número que corresponde a opção desejada: 2
#
# Lista de Tarefas:
# 1. [X] arrumar a casa
#
# Menu:
# 1. Adicionar Tarefa
# 2. Visualizar Tarefas
# 3. Marcar Tarefa como Concluída
# 4. Remover Tarefa
# 5. Sair
# Digite o número que corresponde a opção desejada: 5
# Saindo do Sistema! Até breve!
